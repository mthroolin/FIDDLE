# %% [markdown]
# ## Test: levels = [0]

# %%
# !rm -rf output-*/

import os
import shutil

# Iterate over all items in the current directory
for item in os.listdir('.'):
    # Check if the item is a directory and starts with 'output-'
    if os.path.isdir(item) and item.startswith('output-'):
        # Remove the directory and its contents
        shutil.rmtree(item)

# %%
# !mkdir -p output-0

# Create the directory if it doesn't exist
os.makedirs('output-0', exist_ok=True)

cur_dir = os.getcwd()

print(cur_dir)
# Out:
# C:\Users\mthro\Desktop\FIDDLE\tests\icd_test

# %%
# ! PYTHONPATH="$PYTHONPATH:../../" \
# python -m FIDDLE.run \
#    --data_fname='./input/data.csv' \
#    --population_fname='./input/pop.csv' \
#    --config_fname='./input/config-0.yaml' \
#    --output_dir='./output-0/' \
#    --T=4 --dt=1.0 \
#    --theta_1=0.001 --theta_2=0.001 --theta_freq=1 \
#    --stats_functions 'min' 'max' 'mean'

import os
import sys
import io
import subprocess

# Set console to UTF-8
os.system('chcp 65001')

# Get current directory, which works on both Unix and Windows
base_dir = os.path.abspath(os.path.join(cur_dir, '../../'))

# Set the PYTHONPATH
python_path = os.environ.get('PYTHONPATH', '')
os.environ['PYTHONPATH'] = 'path/to/directory/containing/FIDDLE'
os.environ['PYTHONPATH'] = f"{python_path}:{base_dir}" if python_path else base_dir

# Set the arguments for the command
data_fname = os.path.join('input', 'data.csv')
population_fname = os.path.join('input', 'pop.csv')
config_fname = os.path.join('input', 'config-0.yaml')
output_dir = os.path.join('output-0')

command = [
    'C:\\Users\\mthro\\anaconda3\\python.exe',
    '-m', 'FIDDLE.run',
    '--data_fname=input\\data.csv',
    '--population_fname=input\\pop.csv',
    '--config_fname=input\\config-0.yaml',
    '--output_dir=output-0',
    '--T=4', '--dt=1.0',
    '--theta_1=0.001', '--theta_2=0.001', '--theta_freq=1',
    '--stats_functions=min', '--stats_functions=max', '--stats_functions=mean', '--impute_method=mean'
]

result = subprocess.run(command, capture_output=True, text=True)

print("Return Code:", result.returncode)
print("Standard Output:", result.stdout)
print("Standard Error:", result.stderr)
# Out:
# Return Code: 0
# Standard Output: Input:
#     Data      : input\data.csv
#     Population: input\pop.csv
#     Config    : input\config-0.yaml
#
# Output directory: output-0
#
# Input arguments:
#     T      = 4.0
#     dt     = 1.0
#     theta_1 = 0.001
#     theta_2 = 0.001
#     theta_freq = 1.0
#     k      = 1 ['mean']
#     impute_method = mean
#
# discretize = yes
#     S discretization bins: to be computed from data
#     X discretization bins: to be computed from data
#
# N = 200
# L = 4
#
#
# ================================================================================
# 1) Pre-filter
# ================================================================================
# Remove rows not in population
# Remove rows with t outside of [0, 4]
# Remove rare variables (<= 0.001)
# Total variables     : 1
# Rare variables      : 0
# Remaining variables : 1
# # rows (original)   : 1861
# # rows (filtered)   : 1861
#
# ================================================================================
# 2) Transform; 3) Post-filter
# ================================================================================
#
# --------------------------------------------------------------------------------
# *) Detecting and parsing value types
# --------------------------------------------------------------------------------
# Parsing hierarchical values
# Saved as: output-0value_types.csv
#
# --------------------------------------------------------------------------------
# *) Separate time-invariant and time-dependent
# --------------------------------------------------------------------------------
# Variables (time-invariant): 19
# Variables (time-dependent): 0
# # rows    (time-invariant): 984
# # rows    (time-dependent): 0
#
# --------------------------------------------------------------------------------
# 2-A) Transform time-invariant data
# --------------------------------------------------------------------------------
# (N × ^d) table            :	 (200, 19)
# number of missing entries :	 2816 out of 3800 total
# Time elapsed: 0.015548 seconds
#
# Output
# S_all, binary features    :	 (200, 21)
# Time elapsed: 0.047588 seconds
#
# --------------------------------------------------------------------------------
# 3-A) Post-filter time-invariant data
# --------------------------------------------------------------------------------
# Original       : 21
# Nearly-constant: 0
# Correlated     : 0
# Time elapsed: 0.047588 seconds
#
# Output
# S: shape=(200, 21), density=0.234
# Total time: 0.047588 seconds
#
#
# Standard Error: C:\Users\mthro\Desktop\FIDDLE\FIDDLE\steps.py:287: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_value = pd.pivot_table(df_in, val_col, ID_col, var_col, 'last', np.nan)

# %%
import numpy as np
import pandas as pd
import json
import sparse

S = sparse.load_npz('output-0/S_all.npz')
S_names = json.load(open('output-0/S_all.feature_names.json', 'r'))
S_index = pd.read_csv('output-0/S.ID.csv').set_index(['ID'])
df_S = pd.DataFrame(S.todense(), columns=S_names, index=S_index.index)

display(df_S)
# Out:
#         ICD9_CODE_value_140-239  ICD9_CODE_value_390-459  \
# ID
# 100536                        0                        0
# 101757                        0                        0
# 102631                        0                        0
# 103251                        0                        0
# 104130                        0                        0
# ...                         ...                      ...
# 197661                        0                        0
# 198214                        0                        0
# 198892                        0                        0
# 199634                        0                        0
# 199724                        0                        0
#
#         ICD9_CODE_value_V01-V91  ICD9_CODE:001-139_value_1.0  \
# ID
# 100536                        0                            1
# 101757                        0                            1
# 102631                        0                            0
# 103251                        1                            0
# 104130                        0                            1
# ...                         ...                          ...
# 197661                        0                            0
# 198214                        0                            0
# 198892                        0                            0
# 199634                        0                            1
# 199724                        0                            1
#
#         ICD9_CODE:140-239_value_1.0  ICD9_CODE:240-279_value_1.0  \
# ID
# 100536                            0                            0
# 101757                            1                            0
# 102631                            0                            0
# 103251                            0                            0
# 104130                            0                            1
# ...                             ...                          ...
# 197661                            0                            1
# 198214                            0                            1
# 198892                            0                            0
# 199634                            1                            1
# 199724                            0                            1
#
#         ICD9_CODE:280-289_value_1.0  ICD9_CODE:290-319_value_1.0  \
# ID
# 100536                            1                            1
# 101757                            1                            1
# 102631                            0                            0
# 103251                            0                            0
# 104130                            1                            1
# ...                             ...                          ...
# 197661                            0                            0
# 198214                            1                            0
# 198892                            0                            0
# 199634                            0                            0
# 199724                            0                            1
#
#         ICD9_CODE:320-389_value_1.0  ICD9_CODE:390-459_value_1.0  ...  \
# ID                                                                ...
# 100536                            0                            0  ...
# 101757                            1                            1  ...
# 102631                            0                            1  ...
# 103251                            0                            0  ...
# 104130                            0                            1  ...
# ...                             ...                          ...  ...
# 197661                            0                            1  ...
# 198214                            1                            1  ...
# 198892                            0                            0  ...
# 199634                            0                            1  ...
# 199724                            1                            1  ...
#
#         ICD9_CODE:520-579_value_1.0  ICD9_CODE:580-629_value_1.0  \
# ID
# 100536                            1                            0
# 101757                            0                            0
# 102631                            0                            0
# 103251                            0                            0
# 104130                            0                            1
# ...                             ...                          ...
# 197661                            0                            1
# 198214                            1                            0
# 198892                            0                            0
# 199634                            1                            0
# 199724                            0                            0
#
#         ICD9_CODE:680-709_value_1.0  ICD9_CODE:710-739_value_1.0  \
# ID
# 100536                            0                            0
# 101757                            1                            0
# 102631                            0                            0
# 103251                            0                            0
# 104130                            0                            0
# ...                             ...                          ...
# 197661                            0                            0
# 198214                            0                            0
# 198892                            0                            0
# 199634                            0                            1
# 199724                            0                            0
#
#         ICD9_CODE:740-759_value_1.0  ICD9_CODE:760-779_value_1.0  \
# ID
# 100536                            0                            0
# 101757                            0                            0
# 102631                            0                            0
# 103251                            0                            0
# 104130                            0                            0
# ...                             ...                          ...
# 197661                            0                            0
# 198214                            0                            0
# 198892                            0                            1
# 199634                            0                            0
# 199724                            0                            0
#
#         ICD9_CODE:780-799_value_1.0  ICD9_CODE:800-999_value_1.0  \
# ID
# 100536                            0                            1
# 101757                            1                            0
# 102631                            0                            1
# 103251                            0                            0
# 104130                            1                            0
# ...                             ...                          ...
# 197661                            0                            1
# 198214                            0                            0
# 198892                            0                            0
# 199634                            0                            0
# 199724                            0                            1
#
#         ICD9_CODE:E000-E999_value_1.0  ICD9_CODE:V01-V91_value_1.0
# ID
# 100536                              1                            0
# 101757                              0                            1
# 102631                              0                            0
# 103251                              0                            0
# 104130                              0                            1
# ...                               ...                          ...
# 197661                              0                            0
# 198214                              0                            0
# 198892                              0                            1
# 199634                              0                            1
# 199724                              0                            0
#
# [200 rows x 21 columns]

# %% [markdown]
# ## Test: levels = [0,1]

# %%
# !mkdir -p output-1
# Out:
# A subdirectory or file -p already exists.
# Error occurred while processing: -p.

# %%
! PYTHONPATH="$PYTHONPATH:../../" \
python -m FIDDLE.run \
    --data_fname='./input/data.csv' \
    --population_fname='./input/pop.csv' \
    --config_fname='./input/config-1.yaml' \
    --output_dir='./output-1/' \
    --T=4 --dt=1.0 \
    --theta_1=0.001 --theta_2=0.001 --theta_freq=1 \
    --stats_functions 'min' 'max' 'mean'
# Out:
# 'PYTHONPATH' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import numpy as np
import pandas as pd
import json
import sparse

S = sparse.load_npz('output-1/S_all.npz')
S_names = json.load(open('output-1/S_all.feature_names.json', 'r'))
S_index = pd.read_csv('output-1/S.ID.csv').set_index(['ID'])
df_S = pd.DataFrame(S.todense(), columns=S_names, index=S_index.index)

display(df_S)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 6
#       3 import json
#       4 import sparse
# ----> 6 S = sparse.load_npz('output-1/S_all.npz')
#       7 S_names = json.load(open('output-1/S_all.feature_names.json', 'r'))
#       8 S_index = pd.read_csv('output-1/S.ID.csv').set_index(['ID'])
#
# File ~\anaconda3\Lib\site-packages\sparse\_io.py:102, in load_npz(filename)
#      71 def load_npz(filename):
#      72     """Load a sparse matrix in numpy's ``.npz`` format from disk.
#      73     Note: This is not binary compatible with scipy's ``save_npz()``
#      74     output. This binary format is not currently stable.
#    (...)
#      99
#     100     """
# --> 102     with np.load(filename) as fp:
#     103         try:
#     104             coords = fp["coords"]
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output-1/S_all.npz'

# %% [markdown]
# ## Test: levels = [0,1,2]

# %%
# !mkdir -p output-2

# %%
! PYTHONPATH="$PYTHONPATH:../../" \
python -m FIDDLE.run \
    --data_fname='./input/data.csv' \
    --population_fname='./input/pop.csv' \
    --config_fname='./input/config-2.yaml' \
    --output_dir='./output-2/' \
    --T=4 --dt=1.0 \
    --theta_1=0.001 --theta_2=0.001 --theta_freq=1 \
    --stats_functions 'min' 'max' 'mean'

# %%
import numpy as np
import pandas as pd
import json
import sparse

S = sparse.load_npz('output-2/S_all.npz')
S_names = json.load(open('output-2/S_all.feature_names.json', 'r'))
S_index = pd.read_csv('output-2/S.ID.csv').set_index(['ID'])
df_S = pd.DataFrame(S.todense(), columns=S_names, index=S_index.index)

display(df_S)
